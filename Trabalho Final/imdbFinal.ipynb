# %% [markdown]
# # Disciplina: Tópicos em Inteligência Computacional
# Instituto Federal do Norte de Minas Gerais Campus Montes Claros <br/>
# Curso: Ciência da Computação <br/>
# Professora: Luciana Balieiro Cosme<br/>
# Equipe: Marianna Leandra, Nayara Thaiza e Samuel Soares <br/>
# **Trabalho Intermediário: Exploração da base de dados do IMDB** <br/>
# Base de dados: https://datasets.imdbws.com/ <br/>
# Ultima atualização da base usada: 20/11/2018 <br/>
# **Objetivo: Analisar os filmes do IMDB com mais avalaiações quanto ao gênero preferido** <br/>

# %% [markdown]
# **Base 1: Títulos** <br/>
# tconst: id do título <br/>
# titleType:o tipo / formato do título (por exemplo, filme, short, tvseries, tvepisode, video, etc) <br/>
# primaryTitle - o título mais popular / o título usado pelos cineastas em materiais promocionais no momento do lançamento <br/>
# originalTitle - título original, no idioma original <br/>
# isAdult (booleano) - 0: título não adulto; 1: título adulto <br/>
# startYear (YYYY) - representa o ano de lançamento de um título. No caso da série de TV, é o ano de início da série <br/>
# endYear (YYYY) - ano final da série de TV. "\ N" para todos os outros tipos de título <br/>
# runtimeMinutes - tempo de execução principal do título, em minutos <br/>
# genres - inclui até três gêneros associados ao título <br/>

# %%
import pandas
import matplotlib.pyplot as plt
#importando base 1
imdbTitulos = pandas.read_csv("titleBasics.tsv", sep='\t',dtype= { "tconst": str,
                                                                'titleType': str,
                                                                'primaryTitle': str,
                                                                'originalTitle': str,
                                                                'isAdult': str,
                                                                'startYear': str,
                                                                'endYear': str,
                                                                'runtimeMinutes': str,
                                                                'genres': str})
imdbTitulos.shape
# Out:
# (5589240, 9)

# %% [markdown]
# **Base 2: Notas dos Títulos** <br/>
# averageRating - média ponderada de todas as classificações individuais de usuários <br/>
# numVotes - número de votos que o título recebeu <br/>

# %%
#importando base 2
imdbNotas=pandas.read_csv("titleRatings.tsv", sep='\t',dtype={
    "tconst": str, 
    'averageRating': str,
    'numVotes': str})


imdbNotas.shape
# Out:
# (913588, 3)

# %%
imdbTitulos.columns[0:9]
# Out:
# Index(['tconst', 'titleType', 'primaryTitle', 'originalTitle', 'isAdult',
#        'startYear', 'endYear', 'runtimeMinutes', 'genres'],
#       dtype='object')

# %%
imdbNotas.columns[0:3]
# Out:
# Index(['tconst', 'averageRating', 'numVotes'], dtype='object')

# %%
tabela = pandas.DataFrame(imdbTitulos, columns=['tconst', 'titleType', 'primaryTitle', 'originalTitle', 'isAdult',
       'startYear', 'endYear', 'runtimeMinutes', 'genres'])
tabela.head(10)
# Out:
#       tconst titleType                                 primaryTitle  \
# 0  tt0000001     short                                   Carmencita
# 1  tt0000002     short                       Le clown et ses chiens
# 2  tt0000003     short                               Pauvre Pierrot
# 3  tt0000004     short                                  Un bon bock
# 4  tt0000005     short                             Blacksmith Scene
# 5  tt0000006     short                            Chinese Opium Den
# 6  tt0000007     short  Corbett and Courtney Before the Kinetograph
# 7  tt0000008     short       Edison Kinetoscopic Record of a Sneeze
# 8  tt0000009     movie                                   Miss Jerry
# 9  tt0000010     short                          Exiting the Factory
#
#                                  originalTitle isAdult startYear endYear  \
# 0                                   Carmencita       0      1894      \N
# 1                       Le clown et ses chiens       0      1892      \N
# 2                               Pauvre Pierrot       0      1892      \N
# 3                                  Un bon bock       0      1892      \N
# 4                             Blacksmith Scene       0      1893      \N
# 5                            Chinese Opium Den       0      1894      \N
# 6  Corbett and Courtney Before the Kinetograph       0      1894      \N
# 7       Edison Kinetoscopic Record of a Sneeze       0      1894      \N
# 8                                   Miss Jerry       0      1894      \N
# 9          La sortie de l'usine Lumière à Lyon       0      1895      \N
#
#   runtimeMinutes                    genres
# 0              1         Documentary,Short
# 1              5           Animation,Short
# 2              4  Animation,Comedy,Romance
# 3             \N           Animation,Short
# 4              1              Comedy,Short
# 5              1                     Short
# 6              1               Short,Sport
# 7              1         Documentary,Short
# 8             45                   Romance
# 9              1         Documentary,Short

# %%
#seleciona os filmes

tabela=tabela.loc[(tabela['titleType'].notnull())]
filmes = tabela[tabela['titleType']=='movie']
filmes.describe()
# Out:
#            tconst titleType primaryTitle originalTitle isAdult startYear  \
# count      509234    509234       509234        509234  509234    509234
# unique     509234         1       445882        454138       2       132
# top     tt1557880     movie         Home            \N       0        \N
# freq            1    509234           47            48  500689     51467
#
#        endYear runtimeMinutes  genres
# count   509234         509234  509234
# unique       1            463    1417
# top         \N             \N   Drama
# freq    509234         189919   88415

# %%
#sudo pip install plotly
import matplotlib.pyplot as plt

colors = ['#00ffff', '#7108e5', '#7ce508', '#e5080e', '#de425b','#8B0000', '#ff7c43','#f7f110', '#ffffff', '#080ee5']

g1 = len(filmes[filmes['genres'] == 'Comedy'])
g2 = len(filmes[filmes['genres'] == 'Romance'])
g3 = len(filmes[filmes['genres'] == 'Documentary'])
g4 = len(filmes[filmes['genres'] == 'Action'])
g5 = len(filmes[filmes['genres'] == 'Sci-Fi'])
g6 = len(filmes[filmes['genres'] == 'Drama'])
g7 = len(filmes[filmes['genres'] == 'Thriller'])
g8 = len(filmes[filmes['genres'] == 'Horror'])

g9 = len(filmes[filmes['genres'] == '\\N'])

total = g1+g2+g3+g4+g5+g6+g7+g8
total2 = 503265  - (total + g9) 

labels = [ 'Comedy', 'Romance', 'Documentary','Action', 'Drama', 
          'Thriller', 'Horror',  'Sem gênero', 'Sci-Fi',
         'Mais de um gênero/Outros']
values = [g1,g2,g3,g4,g6,g7,  g8,g9,g5, total2]


plt.pie(values, labels = labels, autopct='%1.1f%%', radius=1800, colors = colors,
        wedgeprops = { 'linewidth' : 1 , 'edgecolor' : 'black'})
plt.legend( bbox_to_anchor=(1.0,1.025), loc="upper left",  labels=['%s, %d' % (l, s) for l, s in zip(labels, values)] )
plt.axis('equal')
plt.suptitle('Gêneros dos filmes', y=1.25, fontsize=18)
plt.title('Principais gêneros de todos os filmes na base do IMDB',y=1.24, fontsize=10)


plt.show()

# %%
#manipulando as notas
notas = pandas.DataFrame(imdbNotas, columns=['tconst', 'averageRating', 'numVotes'])
notas.head(10)
# Out:
#       tconst averageRating numVotes
# 0  tt0000001           5.8     1458
# 1  tt0000002           6.4      175
# 2  tt0000003           6.6     1068
# 3  tt0000004           6.4      104
# 4  tt0000005           6.2     1770
# 5  tt0000006           5.6       94
# 6  tt0000007           5.5      584
# 7  tt0000008           5.6     1556
# 8  tt0000009           5.5       74
# 9  tt0000010           6.9     5201

# %%
notas.describe()
# Out:
#            tconst averageRating numVotes
# count      913588        913588   913588
# unique     913588            91    16640
# top     tt0018696           7.2        6
# freq            1         34047    66909

# %%
#convertendo de texto para numeros
notas['averageRating'] = pandas.to_numeric(notas['averageRating'])
notas['numVotes'] = pandas.to_numeric(notas['numVotes'])

notas.describe()
# Out:
#        averageRating      numVotes
# count  913588.000000  9.135880e+05
# mean        6.913358  9.612321e+02
# std         1.401184  1.540556e+04
# min         1.000000  5.000000e+00
# 25%         6.200000  9.000000e+00
# 50%         7.100000  2.000000e+01
# 75%         7.900000  7.600000e+01
# max        10.000000  2.045224e+06

# %%
print('Maior nota: %s' % notas['averageRating'].max())
print('Maior quantidade de votos: %s' % notas['numVotes'].max())
tituloMaisVotado =  notas[notas['numVotes'] == 2017298]['tconst']
print('ID do título com mais votos:', tituloMaisVotado)
#filmeMaiorNota = notas[notas['averageRating'] == 10.0]['tconst']
#print('Filme maior nota', filmeMaiorNota)
# Out:
# Maior nota: 10.0
# Maior quantidade de votos: 2045224
# ID do título com mais votos: Series([], Name: tconst, dtype: object)

# %%
#Filme com mais votos (se o título com mais votos for filme)
print('Nome do filme com mais votos:')
filmes[filmes['tconst'] == 'tt0111161']['primaryTitle']
# Out:
# Nome do filme com mais votos:
# 108782    The Shawshank Redemption
# Name: primaryTitle, dtype: object

# %%
#titulos com mais de 500 mil votos
titulosFiltro = notas[notas['numVotes'] > 500000],['tconst','averageRating']
titulosFiltro
#titulosFiltro[0]['tconst']
# Out:
# (           tconst  averageRating  numVotes
#  28386   tt0050083            8.9    576000
#  31877   tt0054215            8.5    523090
#  37008   tt0060196            8.9    607073
#  39010   tt0062622            8.3    528690
#  42652   tt0066921            8.3    673222
#  44165   tt0068646            9.2   1402715
#  46658   tt0071562            9.0    972474
#  48275   tt0073486            8.7    812212
#  49808   tt0075314            8.3    621145
#  51017   tt0076759            8.6   1096913
#  52724   tt0078748            8.5    696433
#  52760   tt0078788            8.5    535927
#  54367   tt0080684            8.8   1027003
#  55047   tt0081505            8.4    759758
#  56303   tt0082971            8.5    792769
#  56887   tt0083658            8.2    614105
#  58992   tt0086190            8.3    842161
#  59048   tt0086250            8.3    649337
#  60716   tt0088247            8.0    713835
#  61152   tt0088763            8.5    909300
#  62744   tt0090605            8.4    588105
#  64815   tt0093058            8.3    594727
#  66493   tt0095016            8.2    706883
#  68665   tt0097576            8.2    619520
#  70469   tt0099685            8.7    882460
#  73145   tt0102926            8.6   1101033
#  73256   tt0103064            8.5    886601
#  75027   tt0105236            8.3    803403
#  76525   tt0107048            8.0    530437
#  76723   tt0107290            8.1    764297
#  ...           ...            ...       ...
#  508316  tt1504320            8.0    582901
#  511298  tt1520211            8.3    768863
#  530325  tt1631867            7.9    534185
#  531361  tt1637725            6.9    530381
#  535476  tt1663202            8.0    598379
#  536820  tt1670345            7.3    542400
#  537742  tt1675434            8.5    655222
#  564639  tt1843866            7.8    634208
#  566238  tt1853728            8.4   1179644
#  569943  tt1877832            8.0    605689
#  577825  tt1951264            7.5    566157
#  581262  tt1981115            7.0    516945
#  585673  tt2015381            8.1    904542
#  586569  tt2024544            8.1    563318
#  593911  tt2084970            8.0    602977
#  595890  tt2096673            8.2    517896
#  617020  tt2267998            8.1    741107
#  618122  tt2278388            8.1    617991
#  619924  tt2294629            7.5    505063
#  632561  tt2395427            7.4    626689
#  639622  tt2488496            8.0    768957
#  644169  tt2562232            7.7    505578
#  645486  tt2582802            8.5    593139
#  658253  tt2802144            7.7    531527
#  667375  tt2975590            6.5    561501
#  686852  tt3315342            8.1    532489
#  697352  tt3498820            7.8    545791
#  706895  tt3659388            8.0    657462
#  731753  tt4154756            8.5    574520
#  752131  tt4574334            8.9    553695
#
#  [186 rows x 3 columns], ['tconst', 'averageRating'])

# %%
#coluna = [i[0:10] for i in titulosFiltro] 
#print(coluna)
print('Quantidade de títulos com mais de 500 mil votos: ', len(titulosFiltro[0]))
# Out:
# Quantidade de títulos com mais de 500 mil votos:  186

# %%
#pegando só os ids dos títulos
coluna = titulosFiltro[0]['tconst']
len(coluna)
# Out:
# 186

# %%
#motrando como visualizar somente os ids dos filmes
filmes['tconst']
# Out:
# 8          tt0000009
# 145        tt0000147
# 332        tt0000335
# 499        tt0000502
# 571        tt0000574
# 611        tt0000615
# 626        tt0000630
# 669        tt0000675
# 670        tt0000676
# 673        tt0000679
# 730        tt0000739
# 784        tt0000793
# 803        tt0000812
# 805        tt0000814
# 829        tt0000838
# 833        tt0000842
# 837        tt0000846
# 841        tt0000850
# 850        tt0000859
# 853        tt0000862
# 858        tt0000867
# 859        tt0000868
# 860        tt0000869
# 870        tt0000879
# 877        tt0000886
# 882        tt0000891
# 931        tt0000941
# 937        tt0000947
# 949        tt0000959
# 973        tt0000984
#              ...
# 5588455    tt9668552
# 5588456    tt9668554
# 5588457    tt9668556
# 5588461    tt9668564
# 5588467    tt9668576
# 5588473    tt9668588
# 5588476    tt9668594
# 5588478    tt9668598
# 5588486    tt9668614
# 5588501    tt9668648
# 5588515    tt9668680
# 5588544    tt9668748
# 5588564    tt9668800
# 5588582    tt9668842
# 5588623    tt9668932
# 5588628    tt9668962
# 5588630    tt9668966
# 5588724    tt9669160
# 5588733    tt9669184
# 5588759    tt9669242
# 5588769    tt9669264
# 5588771    tt9669270
# 5588868    tt9669470
# 5589107    tt9669966
# 5589154    tt9670062
# 5589170    tt9670098
# 5589202    tt9670172
# 5589205    tt9670180
# 5589233    tt9670262
# 5589237    tt9670304
# Name: tconst, Length: 509234, dtype: object

# %%
#motrando como visualizar somente os ids dos titulos (não necessariamente só filmes) com mais de 500 mil votos
coluna
# Out:
# 28386     tt0050083
# 31877     tt0054215
# 37008     tt0060196
# 39010     tt0062622
# 42652     tt0066921
# 44165     tt0068646
# 46658     tt0071562
# 48275     tt0073486
# 49808     tt0075314
# 51017     tt0076759
# 52724     tt0078748
# 52760     tt0078788
# 54367     tt0080684
# 55047     tt0081505
# 56303     tt0082971
# 56887     tt0083658
# 58992     tt0086190
# 59048     tt0086250
# 60716     tt0088247
# 61152     tt0088763
# 62744     tt0090605
# 64815     tt0093058
# 66493     tt0095016
# 68665     tt0097576
# 70469     tt0099685
# 73145     tt0102926
# 73256     tt0103064
# 75027     tt0105236
# 76525     tt0107048
# 76723     tt0107290
#             ...
# 508316    tt1504320
# 511298    tt1520211
# 530325    tt1631867
# 531361    tt1637725
# 535476    tt1663202
# 536820    tt1670345
# 537742    tt1675434
# 564639    tt1843866
# 566238    tt1853728
# 569943    tt1877832
# 577825    tt1951264
# 581262    tt1981115
# 585673    tt2015381
# 586569    tt2024544
# 593911    tt2084970
# 595890    tt2096673
# 617020    tt2267998
# 618122    tt2278388
# 619924    tt2294629
# 632561    tt2395427
# 639622    tt2488496
# 644169    tt2562232
# 645486    tt2582802
# 658253    tt2802144
# 667375    tt2975590
# 686852    tt3315342
# 697352    tt3498820
# 706895    tt3659388
# 731753    tt4154756
# 752131    tt4574334
# Name: tconst, Length: 186, dtype: object

# %%
#pegando somente um valor
coluna[0:1]
# Out:
# 28386    tt0050083
# Name: tconst, dtype: object

# %%
#como acessar uma posição da lista
filmes.loc[8]
# Out:
# tconst             tt0000009
# titleType              movie
# primaryTitle      Miss Jerry
# originalTitle     Miss Jerry
# isAdult                    0
# startYear               1894
# endYear                   \N
# runtimeMinutes            45
# genres               Romance
# Name: 8, dtype: object

# %%
filmes.loc[8, 'tconst']
# Out:
# 'tt0000009'

# %%
#encontra todos os matches entre as duas listas (interseção)
#vai filtrar os filmes dentre todos os títulos com mais de 500 mil votos
idFilmes = set(coluna) & set(filmes['tconst'])
#idFilmes
print('Quantidade de matches: ', len(idFilmes))
# Out:
# Quantidade de matches:  177

# %%
#Convertendo set em lista
idFilmesList = list(idFilmes)
len(idFilmesList)
# Out:
# 177

# %%
idFilmesList[0]
# Out:
# 'tt0167404'

# %%
#idFilmesList são os ids de todos os filmes que possuem mais de 500 mil votos
#listando todos os nomes dos filmes filtrados e suas notas
i = 0
while i < len(idFilmesList):
    nome = filmes[filmes['tconst'] == idFilmesList[i]]['primaryTitle']
    nota = notas[notas['tconst'] == idFilmesList[i]]['averageRating']
    genres = filmes[filmes['tconst'] == idFilmesList[i]]['genres']
    print('Nome do filme: ', nome.values)
    print('Nota: ', nota.values)
    i = i+1
# Out:
# Nome do filme:  ['The Sixth Sense']
# Nota:  [8.1]
# Nome do filme:  ['Good Will Hunting']
# Nota:  [8.3]
# Nome do filme:  ['Up']
# Nota:  [8.3]
# Nome do filme:  ['Toy Story']
# Nota:  [8.3]
# Nome do filme:  ["Pirates of the Caribbean: At World's End"]
# Nota:  [7.1]
# Nome do filme:  ['2001: A Space Odyssey']
# Nota:  [8.3]
# Nome do filme:  ['Blade Runner']
# Nota:  [8.2]
# Nome do filme:  ['Whiplash']
# Nota:  [8.5]
# Nome do filme:  ['Alien']
# Nota:  [8.5]
# Nome do filme:  ["One Flew Over the Cuckoo's Nest"]
# Nota:  [8.7]
# Nome do filme:  ['The Lion King']
# Nota:  [8.5]
# Nome do filme:  ['Star Wars: Episode VI - Return of the Jedi']
# Nota:  [8.3]
# Nome do filme:  ['Fight Club']
# Nota:  [8.8]
# Nome do filme:  ['The Bourne Ultimatum']
# Nota:  [8.]
# Nome do filme:  ['The Dark Knight']
# Nota:  [9.]
# Nome do filme:  ['Captain America: The First Avenger']
# Nota:  [6.9]
# Nome do filme:  ['Saving Private Ryan']
# Nota:  [8.6]
# Nome do filme:  ['Aliens']
# Nota:  [8.4]
# Nome do filme:  ['Sherlock Holmes']
# Nota:  [7.6]
# Nome do filme:  ['Captain America: The Winter Soldier']
# Nota:  [7.8]
# Nome do filme:  ['Ted']
# Nota:  [6.9]
# Nome do filme:  ['The Shawshank Redemption']
# Nota:  [9.3]
# Nome do filme:  ["Pirates of the Caribbean: Dead Man's Chest"]
# Nota:  [7.3]
# Nome do filme:  ['Forrest Gump']
# Nota:  [8.8]
# Nome do filme:  ['A Clockwork Orange']
# Nota:  [8.3]
# Nome do filme:  ['The Dark Knight Rises']
# Nota:  [8.4]
# Nome do filme:  ['The Hobbit: An Unexpected Journey']
# Nota:  [7.9]
# Nome do filme:  ['Into the Wild']
# Nota:  [8.1]
# Nome do filme:  ['Kill Bill: Vol. 2']
# Nota:  [8.]
# Nome do filme:  ['Die Hard']
# Nota:  [8.2]
# Nome do filme:  ['Gladiator']
# Nota:  [8.5]
# Nome do filme:  ['Terminator 2: Judgment Day']
# Nota:  [8.5]
# Nome do filme:  ['Iron Man 2']
# Nota:  [7.]
# Nome do filme:  ['Ratatouille']
# Nota:  [8.]
# Nome do filme:  ['Slumdog Millionaire']
# Nota:  [8.]
# Nome do filme:  ['Eternal Sunshine of the Spotless Mind']
# Nota:  [8.3]
# Nome do filme:  ['Star Trek']
# Nota:  [8.]
# Nome do filme:  ['Edge of Tomorrow']
# Nota:  [7.9]
# Nome do filme:  ['Sin City']
# Nota:  [8.]
# Nome do filme:  ['The Intouchables']
# Nota:  [8.5]
# Nome do filme:  ['How to Train Your Dragon']
# Nota:  [8.1]
# Nome do filme:  ['X-Men']
# Nota:  [7.4]
# Nome do filme:  ['Psycho']
# Nota:  [8.5]
# Nome do filme:  ['Kingsman: The Secret Service']
# Nota:  [7.7]
# Nome do filme:  ['Life Is Beautiful']
# Nota:  [8.6]
# Nome do filme:  ['Interstellar']
# Nota:  [8.6]
# Nome do filme:  ['The Green Mile']
# Nota:  [8.5]
# Nome do filme:  ['Toy Story 3']
# Nota:  [8.3]
# Nome do filme:  ['Kill Bill: Vol. 1']
# Nota:  [8.1]
# Nome do filme:  ['Logan']
# Nota:  [8.1]
# Nome do filme:  ['Requiem for a Dream']
# Nota:  [8.3]
# Nome do filme:  ['The Godfather: Part II']
# Nota:  [9.]
# Nome do filme:  ['Pulp Fiction']
# Nota:  [8.9]
# Nome do filme:  ['The Silence of the Lambs']
# Nota:  [8.6]
# Nome do filme:  ['Titanic']
# Nota:  [7.8]
# Nome do filme:  ['Back to the Future']
# Nota:  [8.5]
# Nome do filme:  ['American Beauty']
# Nota:  [8.4]
# Nome do filme:  ['Léon: The Professional']
# Nota:  [8.6]
# Nome do filme:  ['The Departed']
# Nota:  [8.5]
# Nome do filme:  ['Avatar']
# Nota:  [7.8]
# Nome do filme:  ['Star Wars: Episode III - Revenge of the Sith']
# Nota:  [7.6]
# Nome do filme:  ['Reservoir Dogs']
# Nota:  [8.3]
# Nome do filme:  ['Black Swan']
# Nota:  [8.]
# Nome do filme:  ['Taxi Driver']
# Nota:  [8.3]
# Nome do filme:  ['V for Vendetta']
# Nota:  [8.2]
# Nome do filme:  ['Prisoners']
# Nota:  [8.1]
# Nome do filme:  ['X-Men: Days of Future Past']
# Nota:  [8.]
# Nome do filme:  ['A Beautiful Mind']
# Nota:  [8.2]
# Nome do filme:  ['The Lord of the Rings: The Fellowship of the Ring']
# Nota:  [8.8]
# Nome do filme:  ['The Shining']
# Nota:  [8.4]
# Nome do filme:  ['The Lord of the Rings: The Return of the King']
# Nota:  [8.9]
# Nome do filme:  ['Star Wars: Episode VII - The Force Awakens']
# Nota:  [8.]
# Nome do filme:  ['Inception']
# Nota:  [8.8]
# Nome do filme:  ['Catch Me If You Can']
# Nota:  [8.1]
# Nome do filme:  ['The Matrix']
# Nota:  [8.7]
# Nome do filme:  ['Full Metal Jacket']
# Nota:  [8.3]
# Nome do filme:  ['Raiders of the Lost Ark']
# Nota:  [8.5]
# Nome do filme:  ['The Big Lebowski']
# Nota:  [8.1]
# Nome do filme:  ['Thor']
# Nota:  [7.]
# Nome do filme:  ['Guardians of the Galaxy']
# Nota:  [8.1]
# Nome do filme:  ['The Social Network']
# Nota:  [7.7]
# Nome do filme:  ["Schindler's List"]
# Nota:  [8.9]
# Nome do filme:  ['Donnie Darko']
# Nota:  [8.1]
# Nome do filme:  ['WALL·E']
# Nota:  [8.4]
# Nome do filme:  ['The Godfather']
# Nota:  [9.2]
# Nome do filme:  ['12 Years a Slave']
# Nota:  [8.1]
# Nome do filme:  ['Finding Nemo']
# Nota:  [8.1]
# Nome do filme:  ['The Martian']
# Nota:  [8.]
# Nome do filme:  ['Spider-Man']
# Nota:  [7.3]
# Nome do filme:  ['Snatch']
# Nota:  [8.3]
# Nome do filme:  ['Mad Max: Fury Road']
# Nota:  [8.1]
# Nome do filme:  ['Amélie']
# Nota:  [8.3]
# Nome do filme:  ['The Hobbit: The Desolation of Smaug']
# Nota:  [7.8]
# Nome do filme:  ['The Imitation Game']
# Nota:  [8.]
# Nome do filme:  ['X-Men: First Class']
# Nota:  [7.7]
# Nome do filme:  ['The Grand Budapest Hotel']
# Nota:  [8.1]
# Nome do filme:  ["Pan's Labyrinth"]
# Nota:  [8.2]
# Nome do filme:  ['World War Z']
# Nota:  [7.]
# Nome do filme:  ['Inside Out']
# Nota:  [8.2]
# Nome do filme:  ['Jurassic Park']
# Nota:  [8.1]
# Nome do filme:  ['Groundhog Day']
# Nota:  [8.]
# Nome do filme:  ['Fargo']
# Nota:  [8.1]
# Nome do filme:  ['Memento']
# Nota:  [8.5]
# Nome do filme:  ['The Hunger Games']
# Nota:  [7.2]
# Nome do filme:  ['The Hangover']
# Nota:  [7.7]
# Nome do filme:  ['Goodfellas']
# Nota:  [8.7]
# Nome do filme:  ['Django Unchained']
# Nota:  [8.4]
# Nome do filme:  ['The Incredibles']
# Nota:  [8.]
# Nome do filme:  ['The Curious Case of Benjamin Button']
# Nota:  [7.8]
# Nome do filme:  ['Skyfall']
# Nota:  [7.8]
# Nome do filme:  ['Drive']
# Nota:  [7.8]
# Nome do filme:  ['Now You See Me']
# Nota:  [7.3]
# Nome do filme:  ['Transformers']
# Nota:  [7.1]
# Nome do filme:  ['Harry Potter and the Deathly Hallows: Part 2']
# Nota:  [8.1]
# Nome do filme:  ['Heat']
# Nota:  [8.2]
# Nome do filme:  ['Scarface']
# Nota:  [8.3]
# Nome do filme:  ['Star Wars: Episode II - Attack of the Clones']
# Nota:  [6.6]
# Nome do filme:  ['300']
# Nota:  [7.7]
# Nome do filme:  ['Million Dollar Baby']
# Nota:  [8.1]
# Nome do filme:  ['Batman Begins']
# Nota:  [8.3]
# Nome do filme:  ['The Terminator']
# Nota:  [8.]
# Nome do filme:  ['Indiana Jones and the Last Crusade']
# Nota:  [8.2]
# Nome do filme:  ['American History X']
# Nota:  [8.5]
# Nome do filme:  ['I Am Legend']
# Nota:  [7.2]
# Nome do filme:  ['The Avengers']
# Nota:  [8.1]
# Nome do filme:  ['Shutter Island']
# Nota:  [8.1]
# Nome do filme:  ['Avengers: Infinity War']
# Nota:  [8.5]
# Nome do filme:  ['Star Wars: Episode IV - A New Hope']
# Nota:  [8.6]
# Nome do filme:  ['Twelve Monkeys']
# Nota:  [8.]
# Nome do filme:  ['The Prestige']
# Nota:  [8.5]
# Nome do filme:  ['The Truman Show']
# Nota:  [8.1]
# Nome do filme:  ['Deadpool']
# Nota:  [8.]
# Nome do filme:  ['Prometheus']
# Nota:  [7.]
# Nome do filme:  ['The Revenant']
# Nota:  [8.]
# Nome do filme:  ['The Usual Suspects']
# Nota:  [8.6]
# Nome do filme:  ['Braveheart']
# Nota:  [8.4]
# Nome do filme:  ['Spirited Away']
# Nota:  [8.6]
# Nome do filme:  ['Gran Torino']
# Nota:  [8.1]
# Nome do filme:  ['The Good, the Bad and the Ugly']
# Nota:  [8.9]
# Nome do filme:  ['Apocalypse Now']
# Nota:  [8.5]
# Nome do filme:  ['Casino Royale']
# Nota:  [8.]
# Nome do filme:  ["The King's Speech"]
# Nota:  [8.]
# Nome do filme:  ['Man of Steel']
# Nota:  [7.1]
# Nome do filme:  ['Avengers: Age of Ultron']
# Nota:  [7.4]
# Nome do filme:  ['Gone Girl']
# Nota:  [8.1]
# Nome do filme:  ['Inglourious Basterds']
# Nota:  [8.3]
# Nome do filme:  ['Pirates of the Caribbean: The Curse of the Black Pearl']
# Nota:  [8.]
# Nome do filme:  ['Star Wars: Episode V - The Empire Strikes Back']
# Nota:  [8.8]
# Nome do filme:  ['The Wolf of Wall Street']
# Nota:  [8.2]
# Nome do filme:  ['Frozen']
# Nota:  [7.5]
# Nome do filme:  ['Se7en']
# Nota:  [8.6]
# Nome do filme:  ["Harry Potter and the Sorcerer's Stone"]
# Nota:  [7.6]
# Nome do filme:  ['Iron Man 3']
# Nota:  [7.2]
# Nome do filme:  ['The Lord of the Rings: The Two Towers']
# Nota:  [8.7]
# Nome do filme:  ['City of God']
# Nota:  [8.6]
# Nome do filme:  ['Jurassic World']
# Nota:  [7.]
# Nome do filme:  ['Shrek']
# Nota:  [7.9]
# Nome do filme:  ['Silver Linings Playbook']
# Nota:  [7.7]
# Nome do filme:  ['Birdman or (The Unexpected Virtue of Ignorance)']
# Nota:  [7.7]
# Nome do filme:  ['The Amazing Spider-Man']
# Nota:  [7.]
# Nome do filme:  ['No Country for Old Men']
# Nota:  [8.1]
# Nome do filme:  ['Thor: The Dark World']
# Nota:  [7.]
# Nome do filme:  ['Life of Pi']
# Nota:  [7.9]
# Nome do filme:  ['The Hunger Games: Catching Fire']
# Nota:  [7.5]
# Nome do filme:  ['Captain America: Civil War']
# Nota:  [7.8]
# Nome do filme:  ['Batman v Superman: Dawn of Justice']
# Nota:  [6.5]
# Nome do filme:  ['12 Angry Men']
# Nota:  [8.9]
# Nome do filme:  ['District 9']
# Nota:  [7.9]
# Nome do filme:  ['The Pianist']
# Nota:  [8.5]
# Nome do filme:  ['Iron Man']
# Nota:  [7.9]
# Nome do filme:  ['Star Wars: Episode I - The Phantom Menace']
# Nota:  [6.5]
# Nome do filme:  ['Trainspotting']
# Nota:  [8.2]
# Nome do filme:  ['Argo']
# Nota:  [7.7]
# Nome do filme:  ['Monsters, Inc.']
# Nota:  [8.1]
# Nome do filme:  ['Suicide Squad']
# Nota:  [6.1]
# Nome do filme:  ['Taken']
# Nota:  [7.8]
# Nome do filme:  ['Gravity']
# Nota:  [7.7]

# %%
#refinando a busca
print('Filmes que possuem mais de 500 mil votos e nota acima de 9:\n')
i = 0
filtro2 = ''
while i < len(idFilmesList):
    notasAcimaNove = notas[notas['averageRating'] > 9]['tconst']
    filtro2 = notasAcimaNove[notas['tconst'] == idFilmesList[i]]
    j = 0
    if filtro2.size > 0:
        #print(filtro2.values)
        nome = filmes[filmes['tconst'] == filtro2.values[j]]['primaryTitle']
        generos = filmes[filmes['tconst'] == filtro2.values[j]]['genres']
        ano = filmes[filmes['tconst'] == filtro2.values[j]]['startYear']
        nota = notas[notas['tconst'] == filtro2.values[j]]['averageRating']
        qtdVotos = notas[notas['tconst'] == filtro2.values[j]]['numVotes']
        print('Nome do filme: ', nome.values)
        print('Ano: ', ano.values)
        print('Gênero(s): ', generos.values)
        print('Nota: ', nota.values)
        print('Quantidade de votos: ', qtdVotos.values)
        print('\n')
        j = j + 1
    i = i+1
# Out:
# Filmes que possuem mais de 500 mil votos e nota acima de 9:
#
# Nome do filme:  ['The Shawshank Redemption']
# Ano:  ['1994']
# Gênero(s):  ['Drama']
# Nota:  [9.3]
# Quantidade de votos:  [2045224]
#
#
# Nome do filme:  ['The Godfather']
# Ano:  ['1972']
# Gênero(s):  ['Crime,Drama']
# Nota:  [9.2]
# Quantidade de votos:  [1402715]

# %%
#Todos os filmes tem no máximo 3 generos e existem 19 generos distintos na amostra de 175 filmes
i = 0
act = 0
adv = 0
ani = 0
bio = 0
cri = 0
com = 0
dra = 0
fam = 0
fan = 0
his = 0
hor = 0
mys = 0
mus = 0
rom = 0
sci = 0
spo = 0
thr = 0
war = 0
wes = 0
while i < len(idFilmesList):
    generos = filmes[filmes['tconst'] == idFilmesList[i]]['genres'].apply(lambda x: x.split(','))
    
    #print(len(generos.values[0]))
    col1 = generos.values[0][0]
    #col2 = generos.values[0][1]
    #col3 = generos.values[0][2]
    if col1 == 'Action' :
        act = act+1
    elif col1 == 'Adventure':
        adv = adv+1
    elif col1 == 'Animation':
        ani = ani+1
    elif col1 == 'Biography':
        bio = bio+1
    elif col1 == 'Crime':
        cri = cri+1
    elif col1 == 'Comedy':
        com = com+1
    elif col1 == 'Drama':
        dra = dra+1
    elif col1 == 'Family':
        fam = fam+1
    elif col1 == 'Fantasy':
        fan = fan+1
    elif col1 == 'History':
        his = his+1
    elif col1 == 'Horror':
        hor = hor+1
    elif col1 == 'Mystery':
        mys = mys+1
    elif col1 == 'Music':
        mus = mus+1
    elif col1 == 'Romance':
        rom = rom+1
    elif col1 == 'Sci-Fi':
        sci = sci+1
    elif col1 == 'Sport':
        spo = spo+1
    elif col1 == 'Thriller':
        thr = thr+1
    elif col1 == 'War':
        war = war+1
    elif col1 == 'Western':
        wes = wes+1
        
    if len(generos.values[0]) == 2:
        col2 = generos.values[0][1]
        if col2 == 'Action' :
            act = act+1
        elif col2 == 'Adventure':
            adv = adv+1
        elif col2 == 'Animation':
            ani = ani+1
        elif col2 == 'Biography':
            bio = bio+1
        elif col2 == 'Crime':
            cri = cri+1
        elif col2 == 'Comedy':
            com = com+1
        elif col2 == 'Drama':
            dra = dra+1
        elif col2 == 'Family':
            fam = fam+1
        elif col2 == 'Fantasy':
            fan = fan+1
        elif col2 == 'History':
            his = his+1
        elif col2 == 'Horror':
            hor = hor+1
        elif col2 == 'Mystery':
            mys = mys+1
        elif col2 == 'Music':
            mus = mus+1
        elif col2 == 'Romance':
            rom = rom+1
        elif col2 == 'Sci-Fi':
            sci = sci+1
        elif col2 == 'Sport':
            spo = spo+1
        elif col2 == 'Thriller':
            thr = thr+1
        elif col2 == 'War':
            war = war+1
        elif col2 == 'Western':
            wes = wes+1
        
    if len(generos.values[0]) == 3:
        col3 = generos.values[0][2]
        if col3 == 'Action' :
            act = act+1
        elif col3 == 'Adventure':
            adv = adv+1
        elif col3 == 'Animation':
            ani = ani+1
        elif col3 == 'Biography':
            bio = bio+1
        elif col3 == 'Crime':
            cri = cri+1
        elif col3 == 'Comedy':
            com = com+1
        elif col3 == 'Drama':
            dra = dra+1
        elif col3 == 'Family':
            fam = fam+1
        elif col3 == 'Fantasy':
            fan = fan+1
        elif col3 == 'History':
            his = his+1
        elif col3 == 'Horror':
            hor = hor+1
        elif col3 == 'Mystery':
            mys = mys+1
        elif col3 == 'Music':
            mus = mus+1
        elif col3 == 'Romance':
            rom = rom+1
        elif col3 == 'Sci-Fi':
            sci = sci+1
        elif col3 == 'Sport':
            spo = spo+1
        elif col3 == 'Thriller':
            thr = thr+1
        elif col3 == 'War':
            war = war+1
        elif col3 == 'Western':
            wes = wes+1
    i = i+1
    
#teste1 
print(act + adv +ani +bio +cri + com +dra+ fam + fan + his+hor + mys+ mus +rom +sci + spo +thr+ war + wes)
# Out:
# 343

# %%
colors = ['#00008B', '#00C5CD', '#006633', '#00FF00','#68228B','#CD69C9','#CC1100','#EE7600','yellow', '#FF69B4', '#4876FF',
          '#458B00','#8B5742','black','white','#6600FF', '#FF34B3','#8B0000','#F5DEB3' ]
labels = ['Action', 'Animation', 'Adventure', 'Family', 'Biography', 'Romance', 'Crime', 'Horror', 'Comedy', 'Music', 'Drama',
          'Sport', 'Fantasy', 'Mystery', 'History', 'Sci-Fi', 'War', 'Thriller',  'Western']

values = [act, ani, adv, fam, bio, rom, cri, hor, com, mus, dra, spo, fan, mys, his, sci, war, thr,  wes]


plt.pie(values, labels = labels, radius=1800, rotatelabels=True, colors=colors,
       wedgeprops = { 'linewidth' : 1 , 'edgecolor' : 'black'})


plt.legend( bbox_to_anchor=(1.0,1.025), loc="upper left",  labels=['%s, %d' % (l, s) for l, s in zip(labels, values)] )
plt.axis('equal')
plt.suptitle('Gêneros dos filmes', y=1.25, fontsize=18)
plt.title('Gênero de todos os filmes com mais de 500 mil votos',y=1.24, fontsize=10)



plt.show()

# %% [markdown]
# **Conclusão final** <br/>
# Dentre 5419681 títulos, 503265 são filmes, totalizando aproximadamente 9% da base. <br/>
# Do total de filmes, somente 175 possuem mais de 500 mil votos, totalizando menos de 0,5%. <br/>
# Destes 175, somente 2 filmes possuem nota acima de 9, The Godfather (1972), conhecido no Brasil como O poderoso chefão e The Shawshank Redemption (1994), entitulado com Um sonho de liberdade em português, com notas 9.2(1382225 votos) e 9.3(2017298 votos), respectivamente. Ambos os filmes possuiam Drama como gênero (The godfather também tem como gênero Crime). <br/>
# Em análise final, é possível perceber (graficamente) que os gêneros que prevaleceram nas avalições foram: Ação e Drama, seguidos de Sci-Fi, Thriller, Adventure, Crime e Fantasy.

# %%
print (" 1-Action \n 2-Animation \n 3-Adventure \n 4-Family \n 5-Biography \n 6-Romance \n 7-Crime \n 8-Horror \n 9-Comedy \n 10-Music \n 11-Drama \n 12-Sport \n 13-Fantasy \n 14-Mystery \n 15-History \n 16-Sci-fi \n 17-War \n 18-Thriller \n 19-Western")
genero = input('Digite o num que corresponde ao seu genero preferido: ')
# Out:
#  1-Action
#  2-Animation
#  3-Adventure
#  4-Family
#  5-Biography
#  6-Romance
#  7-Crime
#  8-Horror
#  9-Comedy
#  10-Music
#  11-Drama
#  12-Sport
#  13-Fantasy
#  14-Mystery
#  15-History
#  16-Sci-fi
#  17-War
#  18-Thriller
#  19-Western
# Digite o num que corresponde ao seu genero preferido: 17

# %%
#imprime os filmes do gênero escolhido
i=0
while i < len(idFilmesList):
    filme = filmes[filmes['tconst'] == idFilmesList[i]]
    gen = filmes[filmes['tconst'] == idFilmesList[i]]['genres'].apply(lambda x: x.split(','))
    #print("antes")
    if genero == '1':
        #print ("dentro")
        c1=gen.values[0][0]
        if c1  == 'Action':
            print(filme)
        elif len(gen.values[0]) == 2:
            c2=gen.values[0][1]
            if c2  == 'Action':
                print(filme)
        elif len(gen.values[0]) == 3:
            c3=c1=gen.values[0][2]
            if c3  == 'Action':
                print(filme)
    elif genero == '2':
        #print ("dentro")
        c1=gen.values[0][0]
        if c1  == 'Animation':
            print(filme)
        elif len(gen.values[0]) == 2:
            c2=gen.values[0][1]
            if c2  == 'Animation':
                print(filme)
        elif len(gen.values[0]) == 3:
            c3=c1=gen.values[0][2]
            if c3  == 'Animation':
                print(filme)
    elif genero == '3':
        #print ("dentro")
        c1=gen.values[0][0]
        if c1  == 'Adventure':
            print(filme)
        elif len(gen.values[0]) == 2:
            c2=gen.values[0][1]
            if c2  == 'Adventure':
                print(filme)
        elif len(gen.values[0]) == 3:
            c3=c1=gen.values[0][2]
            if c3  == 'Adventure':
                print(filme)
    elif genero == '4':
        #print ("dentro")
        c1=gen.values[0][0]
        if c1  == 'Family':
            print(filme)
        elif len(gen.values[0]) == 2:
            c2=gen.values[0][1]
            if c2  == 'Family':
                print(filme)
        elif len(gen.values[0]) == 3:
            c3=c1=gen.values[0][2]
            if c3  == 'Family':
                print(filme)
    elif genero == '5':
        #print ("dentro")
        c1=gen.values[0][0]
        if c1  == 'Biography':
            print(filme)
        elif len(gen.values[0]) == 2:
            c2=gen.values[0][1]
            if c2  == 'Biography':
                print(filme)
        elif len(gen.values[0]) == 3:
            c3=c1=gen.values[0][2]
            if c3  == 'Biography':
                print(filme)
    elif genero == '6':
        #print ("dentro")
        c1=gen.values[0][0]
        if c1  == 'Romance':
            print(filme)
        elif len(gen.values[0]) == 2:
            c2=gen.values[0][1]
            if c2  == 'Romance':
                print(filme)
        elif len(gen.values[0]) == 3:
            c3=c1=gen.values[0][2]
            if c3  == 'Romance':
                print(filme)
    elif genero == '7':
        #print ("dentro")
        c1=gen.values[0][0]
        if c1  == 'Crime':
            print(filme)
        elif len(gen.values[0]) == 2:
            c2=gen.values[0][1]
            if c2  == 'Crime':
                print(filme)
        elif len(gen.values[0]) == 3:
            c3=c1=gen.values[0][2]
            if c3  == 'Crime':
                print(filme)
    elif genero == '8':
        #print ("dentro")
        c1=gen.values[0][0]
        if c1  == 'Horror':
            print(filme)
        elif len(gen.values[0]) == 2:
            c2=gen.values[0][1]
            if c2  == 'Horror':
                print(filme)
        elif len(gen.values[0]) == 3:
            c3=c1=gen.values[0][2]
            if c3  == 'Horror':
                print(filme)
    elif genero == '9':
        #print ("dentro")
        c1=gen.values[0][0]
        if c1  == 'Comedy':
            print(filme)
        elif len(gen.values[0]) == 2:
            c2=gen.values[0][1]
            if c2  == 'Comedy':
                print(filme)
        elif len(gen.values[0]) == 3:
            c3=c1=gen.values[0][2]
            if c3  == 'Comedy':
                print(filme)
    elif genero == '10':
        #print ("dentro")
        c1=gen.values[0][0]
        if c1  == 'Music':
            print(filme)
        elif len(gen.values[0]) == 2:
            c2=gen.values[0][1]
            if c2  == 'Music':
                print(filme)
        elif len(gen.values[0]) == 3:
            c3=c1=gen.values[0][2]
            if c3  == 'Music':
                print(filme)
    elif genero == '11':
        #print ("dentro")
        c1=gen.values[0][0]
        if c1  == 'Drama':
            print(filme)
        elif len(gen.values[0]) == 2:
            c2=gen.values[0][1]
            if c2  == 'Drama':
                print(filme)
        elif len(gen.values[0]) == 3:
            c3=c1=gen.values[0][2]
            if c3  == 'Drama':
                print(filme)
    elif genero == '12':
        #print ("dentro")
        c1=gen.values[0][0]
        if c1  == 'Sport':
            print(filme)
        elif len(gen.values[0]) == 2:
            c2=gen.values[0][1]
            if c2  == 'Sport':
                print(filme)
        elif len(gen.values[0]) == 3:
            c3=c1=gen.values[0][2]
            if c3  == 'Sport':
                print(filme)
    elif genero == '13':
        #print ("dentro")
        c1=gen.values[0][0]
        if c1  == 'Fantasy':
            print(filme)
        elif len(gen.values[0]) == 2:
            c2=gen.values[0][1]
            if c2  == 'Fantasy':
                print(filme)
        elif len(gen.values[0]) == 3:
            c3=c1=gen.values[0][2]
            if c3  == 'Fantasy':
                print(filme)
    elif genero == '14':
        #print ("dentro")
        c1=gen.values[0][0]
        if c1  == 'Mystery':
            print(filme)
        elif len(gen.values[0]) == 2:
            c2=gen.values[0][1]
            if c2  == 'Mystery':
                print(filme)
        elif len(gen.values[0]) == 3:
            c3=c1=gen.values[0][2]
            if c3  == 'Mystery':
                print(filme)
    elif genero == '15':
        #print ("dentro")
        c1=gen.values[0][0]
        if c1  == 'History':
            print(filme)
        elif len(gen.values[0]) == 2:
            c2=gen.values[0][1]
            if c2  == 'History':
                print(filme)
        elif len(gen.values[0]) == 3:
            c3=c1=gen.values[0][2]
            if c3  == 'History':
                print(filme)
    elif genero == '16':
        #print ("dentro")
        c1=gen.values[0][0]
        if c1  == 'Sci-fi':
            print(filme)
        elif len(gen.values[0]) == 2:
            c2=gen.values[0][1]
            if c2  == 'Sci-fi':
                print(filme)
        elif len(gen.values[0]) == 3:
            c3=c1=gen.values[0][2]
            if c3  == 'Sci-fi':
                print(filme)
    elif genero == '17':
        #print ("dentro")
        c1=gen.values[0][0]
        if c1  == 'War':
            print(filme)
        elif len(gen.values[0]) == 2:
            c2=gen.values[0][1]
            if c2  == 'War':
                print(filme)
        elif len(gen.values[0]) == 3:
            c3=c1=gen.values[0][2]
            if c3  == 'War':
                print(filme)
    elif genero == '18':
        #print ("dentro")
        c1=gen.values[0][0]
        if c1  == 'Thriller':
            print(filme)
        elif len(gen.values[0]) == 2:
            c2=gen.values[0][1]
            if c2  == 'Thriller':
                print(filme)
        elif len(gen.values[0]) == 3:
            c3=c1=gen.values[0][2]
            if c3  == 'Thriller':
                print(filme)
    elif genero == '19':
        #print ("dentro")
        c1=gen.values[0][0]
        if c1  == 'Western':
            print(filme)
        elif len(gen.values[0]) == 2:
            c2=gen.values[0][1]
            if c2  == 'Western':
                print(filme)
        elif len(gen.values[0]) == 3:
            c3=c1=gen.values[0][2]
            if c3  == 'Western':
                print(filme)
    #print("depois")        
    i=i+1
# Out:
#            tconst titleType         primaryTitle        originalTitle isAdult  \
# 118046  tt0120815     movie  Saving Private Ryan  Saving Private Ryan       0
#
#        startYear endYear runtimeMinutes     genres
# 118046      1998      \N            169  Drama,War
#           tconst titleType       primaryTitle      originalTitle isAdult  \
# 91058  tt0093058     movie  Full Metal Jacket  Full Metal Jacket       0
#
#       startYear endYear runtimeMinutes     genres
# 91058      1987      \N            116  Drama,War
#            tconst titleType     primaryTitle           originalTitle isAdult  \
# 440037  tt0457430     movie  Pan's Labyrinth  El laberinto del fauno       0
#
#        startYear endYear runtimeMinutes             genres
# 440037      2006      \N            118  Drama,Fantasy,War
#           tconst titleType    primaryTitle   originalTitle isAdult startYear  \
# 77163  tt0078788     movie  Apocalypse Now  Apocalypse Now       0      1979
#
#       endYear runtimeMinutes     genres
# 77163      \N            147  Drama,War
#            tconst titleType          primaryTitle         originalTitle  \
# 347281  tt0361748     movie  Inglourious Basterds  Inglourious Basterds
#
#        isAdult startYear endYear runtimeMinutes               genres
# 347281       0      2009      \N            153  Adventure,Drama,War
